# %%
import pandas as pd
import numpy as np

from collections import namedtuple, defaultdict

# %%
read_file = pd.read_csv('./resource/train.tsv', sep='\t')
test_file = pd.read_csv('./resource/test.tsv', sep='\t')

corpus_file = pd.read_excel('./resource/harvard_copus_excel.xlsx')

# %%
preprocess_df1 = pd.concat([corpus_file['Entry'], corpus_file['Positiv'], corpus_file['Negativ']
                            , corpus_file['IAV'], corpus_file['Strong'] ], axis=1)

# %%
c = [row[0] for row in preprocess_df1[:10000]] 
print(c)
# Out:
# [u'E', u'P', u'N', u'I', u'S']

# %%
preprocess_df1
# Out:
#               Entry  Positiv  Negativ  IAV  Strong
# 0                 A      NaN      NaN  NaN     NaN
# 1           ABANDON      NaN  Negativ  IAV     NaN
# 2       ABANDONMENT      NaN  Negativ  NaN     NaN
# 3             ABATE      NaN  Negativ  IAV     NaN
# 4         ABATEMENT      NaN      NaN  NaN     NaN
# 5          ABDICATE      NaN  Negativ  IAV     NaN
# 6             ABHOR      NaN  Negativ  NaN     NaN
# 7             ABIDE  Positiv      NaN  IAV     NaN
# 8           ABILITY  Positiv      NaN  NaN  Strong
# 9            ABJECT      NaN  Negativ  NaN     NaN
# 10             ABLE  Positiv      NaN  NaN  Strong
# 11         ABNORMAL      NaN  Negativ  NaN     NaN
# 12           ABOARD      NaN      NaN  NaN     NaN
# 13          ABOLISH      NaN  Negativ  IAV  Strong
# 14        ABOLITION      NaN      NaN  NaN     NaN
# 15       ABOMINABLE      NaN  Negativ  NaN  Strong
# 16         ABORTIVE      NaN      NaN  NaN     NaN
# ...

# %%
corpus = defaultdict(list)
it = preprocess_df1
next(it)  # Drop header row
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-2803166bb211> in <module>()
#       1 corpus = defaultdict(list)
#       2 it = preprocess_df1
# ----> 3 next(it)  # Drop header row
#
# TypeError: DataFrame object is not an iterator

# %%
for row in preprocess_df1.iteritems():
    print(row)
# Out:
# (u'Entry', 0                   A
# 1             ABANDON
# 2         ABANDONMENT
# 3               ABATE
# 4           ABATEMENT
# 5            ABDICATE
# 6               ABHOR
# 7               ABIDE
# 8             ABILITY
# 9              ABJECT
# 10               ABLE
# 11           ABNORMAL
# 12             ABOARD
# 13            ABOLISH
# 14          ABOLITION
# 15         ABOMINABLE
# 16           ABORTIVE
# 17             ABOUND
# 18            ABOUT#1
# 19            ABOUT#2
# 20            ABOUT#3
# 21            ABOUT#4
# 22            ABOUT#5
# 23            ABOUT#6
# 24            ABOUT#7
# 25            ABOVE#1
# 26            ABOVE#2
# 27            ABOVE#3
# 28            ABOVE#4
# 29           ABRASIVE
#              ...
# 11758         YIELD#2
# 11759            YOKE
# 11760          YONDER
# 11761            YORK
# 11762           YOU#1
# 11763           YOU#2
# 11764           YOU#3
# 11765           YOU#4
# 11766         YOUNG#1
# 11767         YOUNG#2
# ...

# %%
for row in preprocess_df1[:,0:]:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e514ac12c768> in <module>()
# ----> 1 for row in preprocess_df1[:,0:]:
#       2     print(row)
#
# c:\python27\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2055             return self._getitem_multilevel(key)
#    2056         else:
# -> 2057             return self._getitem_column(key)
#    2058
#    2059     def _getitem_column(self, key):
#
# c:\python27\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2062         # get column
#    2063         if self.columns.is_unique:
# -> 2064             return self._get_item_cache(key)
#    2065
#    2066         # duplicate columns & possible reduce dimensionality
#
# c:\python27\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
# ...

# %%
preprocess_df1.values
# Out:
# array([[u'A', nan, nan, nan, nan],
#        [u'ABANDON', nan, u'Negativ', u'IAV', nan],
#        [u'ABANDONMENT', nan, u'Negativ', nan, nan],
#        ...,
#        [u'ZEST', u'Positiv', nan, nan, u'Strong'],
#        [u'ZINC', nan, nan, nan, nan],
#        [u'ZONE', nan, nan, nan, nan]], dtype=object)

# %%
read_file.head(100)
# Out:
#     PhraseId  SentenceId                                             Phrase  \
# 0          1           1  A series of escapades demonstrating the adage ...
# 1          2           1  A series of escapades demonstrating the adage ...
# 2          3           1                                           A series
# 3          4           1                                                  A
# 4          5           1                                             series
# 5          6           1  of escapades demonstrating the adage that what...
# 6          7           1                                                 of
# 7          8           1  escapades demonstrating the adage that what is...
# 8          9           1                                          escapades
# 9         10           1  demonstrating the adage that what is good for ...
# 10        11           1                            demonstrating the adage
# ...
